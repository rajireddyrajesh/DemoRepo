# %%
print("Hello World!")

# %%
# %sql
Select "Hello World from SQL"

# %% [markdown]
# # Title1
# ## Title2
# ### Title3

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls 'databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files=dbutils.fs.ls('databricks-datasets')
display(files)
